# %%
#Importing Values
import pandas as pd
import numpy as np

#np.r_[list] translates slice objects to concatenation along the first axis, so creates an array 
#along the first axis, can still use incremental notation such as [2:10:2] which means going from 
#2 to 10, skipping by 2

data = pd.read_csv(
    r'C:\Users\Isiah Turner\OneDrive\Documents\Final Project 2022\S1_DP_01_WM.csv',
    sep='\t', index_col = "ITEM", usecols= np.r_[0, 4], skiprows= 4, nrows = 767)


print(data)

#This is how you isolate a single value
print("\n", data.iloc[0]['X.3']) 

# This is how you can pull specific values and run calculations with them. Use loc or iloc
# iloc and loc go by [rows][columns]
seg = data.iloc[0]['X.3'] - data.iloc[1]['X.3']
print(seg)
print(type(seg))

#Testing to see how loops would interact by first seeing how to select a specific column, should
#select all of column X.3 
print("\n", data.iloc[:]['X.3'])

# This is so you can get a final value for the length, the code above gives length but not the 
# physical value that is stored
print(len(data.iloc[:]['X.3']))

# Now testing how the dataframe will interact with loops
testList = []
for i in range(3):
    x = data.iloc[i]['X.3'] + 1
    testList.append(x)

print(testList)


data = data.rename({'X.3':'X'})
# Out:
#            X.3
# ITEM
# 1     0.295022
# 2     0.295046
# 3     0.295061
# 4     0.295086
# 5     0.295100
# ...        ...
# 763   0.415137
# 764   0.414680
# 765   0.414588
# 766   0.414113
# 767   0.414061
#
# [767 rows x 1 columns]
#
#  0.295022
# -2.399999999996849e-05
# <class 'numpy.float64'>
#
#  ITEM
# 1      0.295022
# 2      0.295046
# 3      0.295061
# 4      0.295086
# 5      0.295100
#          ...
# 763    0.415137
# 764    0.414680
# 765    0.414588
# 766    0.414113
# 767    0.414061
# Name: X.3, Length: 767, dtype: float64
# 767
# [1.295022, 1.295046, 1.295061]

# %%
#Importing Values
import pandas as pd
import numpy as np

#np.r_[list] translates slice objects to concatenation along the first axis, so creates an array 
#along the first axis, can still use incremental notation such as [2:10:2] which means going from 
#2 to 10, skipping by 2

data = pd.read_csv(
    r'C:\Users\Isiah Turner\OneDrive\Documents\Final Project 2022\S1_DP_01_WM.csv',
    sep='\t', usecols= np.r_[4:190], skiprows= [0, 2, 3], nrows = 768)

#Visualizing the data set
#print(data)

#Testing to see what the first row was looking like when using markers as columns
# print(data.iloc[0])
#print(data.iloc[1:5]['LFHD'])

# Testing out how the data is interacting, imported this way causes the data to be strings
# so need to cast the str to float
count = 1

x= float(data.iloc[1]['LFHD'])
x+= 1
print(x)
print(type(x))
#print(type(data.iloc[1]['LFHD']))

# This would be the data set without the X, Y, Z if I wanted to separate it again
data2 = data.iloc[1:][:]

#Testing how the dataframe interacts throughout a loop
for point in range(len(data.iloc[1:4]['LFHD'])):
    print(data.iloc[point+1]['LFHD'])
    #x = float(point) + 100
    #print(x)
    #print(type(x))


for point in range(len(data.iloc[1:4]['LFHD'])):
    x = data.iloc[point]['RFHD']
    print(type(x))

print(type(data.iloc[1:]['LFHD']))
# Out:
# 1.295022
# <class 'float'>
# 0.295022
# 0.295046
# 0.295061
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'pandas.core.series.Series'>

# %%
#Importing Values
import pandas as pd
import numpy as np

#np.r_[list] translates slice objects to concatenation along the first axis, so creates an array 
#along the first axis, can still use incremental notation such as [2:10:2] which means going from 
#2 to 10, skipping by 2

data = pd.read_csv(
    r'C:\Users\Isiah Turner\OneDrive\Documents\Final Project 2022\S1_DP_01_WM.csv',
    sep='\t', usecols= np.r_[4:190], skiprows= [0, 2, 3], nrows = 768)

#Visualizing the data
#print(data)

#Checking how the naming works for the cluster points
print(data.iloc[1:5]['RSK1'])
print(data.iloc[1:5]['RSK2'])
print(data.iloc[1:5]['RSK3'])
print(data.iloc[1:5]['RSK4'])
print(data.iloc[1:5]['RSK1.1'])

# Now working on iterating through the desired markers and to do their distance apart
emptylist = []
for point in range(len(data.iloc[1:5]['RSK2.2'])):
    proximal = float(data.iloc[point+1]['RSK2.2'])
    distal = float(data.iloc[point+1]['RSK4.2'])
    
    segLength = (proximal - distal)
    print(segLength)
    emptylist.append(segLength)

print(emptylist)

# Having trouble visualizing at the moment, but getting close.
# Remember that the process above finds the information in the Z direction, now I need the X or Y direction 
# I am pretty sure
# Out:
# 1    0.142956
# 2    0.142952
# 3    0.142960
# 4    0.142967
# Name: RSK1, dtype: object
# 1    0.112802
# 2    0.112798
# 3    0.112812
# 4    0.112802
# Name: RSK2, dtype: object
# 1    0.158434
# 2    0.158411
# 3    0.158425
# 4    0.158458
# Name: RSK3, dtype: object
# 1    0.130423
# 2    0.130402
# 3    0.130453
# 4    0.130435
# Name: RSK4, dtype: object
# 1    0.847366
# 2    0.847373
# 3    0.847382
# 4    0.847406
# Name: RSK1.1, dtype: object
# 0.07100400000000001
# 0.07098900000000002
# 0.071042
# 0.07102399999999998
# [0.07100400000000001, 0.07098900000000002, 0.071042, 0.07102399999999998]
